# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
business_objectives = {
    "background": (
        "Phishing attacks are a major cybersecurity threat, where malicious URLs are used "
        "to trick users into revealing sensitive information. Traditional detection methods "
        "often rely on page content or blacklists, which can be too slow for real-time protection. "
        "This project focuses on detecting malicious URLs using only lexical features available "
        "before the webpage loads."
    ),

    "primary_objective": (
        "Develop a machine learning model that can accurately classify URLs as benign, malware, "
        "or phishing using only lexical features (e.g., URL length, special characters, "
        "obfuscation patterns) in real-time."
    ),

    "success_criteria": [
        "Achieve high recall (>90%) for phishing URLs to minimize missed attacks",
        "Maintain precision above 85% to reduce false positives",
        "Model inference time fast enough for real-time use (<100ms per URL)",
        "Model generalizes well on unseen/test data (no major overfitting)",
        "Feature extraction pipeline works without requiring webpage content"
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    Phishing attacks are a major cybersecurity threat, where malicious URLs are used to trick users into revealing sensitive information. Traditional detection methods often rely on page content or blacklists, which can be too slow for real-time protection. This project focuses on detecting malicious URLs using only lexical features available before the webpage loads.
#
# >> PRIMARY OBJECTIVE:
#    Develop a machine learning model that can accurately classify URLs as benign, malware, or phishing using only lexical features (e.g., URL length, special characters, obfuscation patterns) in real-time.
#
# >> SUCCESS CRITERIA:
#    - Achieve high recall (>90%) for phishing URLs to minimize missed attacks
#    - Maintain precision above 85% to reduce false positives
#    - Model inference time fast enough for real-time use (<100ms per URL)
#    - Model generalizes well on unseen/test data (no major overfitting)
# ...

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.

situation_assessment = {
    "resources": {
        "personnel": [
            "Single student (Data Scientist role)"
        ],
        "data_sources": [
            "Malicious URL Dataset (Kaggle)",
            "Malicious URLs Dataset (40k Samples) from Kaggle"
            "Web scraping additional URLs for augmentation if needed"
        ],
        "computing": (
            "Local machine (laptop) using CPU-based processing. "
            "Google Collab for heavier workloads."
        ),
        "software": [
            "Python 3.13.1",
            "pandas",
            "numpy",
            "scikit-learn",
            "matplotlib / seaborn",
            "BeautifulSoup / Selenium (for scraping)",
            "Jupyter Notebook",
            "Git & GitHub"
        ]
    },

    "requirements": [
        "Project must follow CRISP-DM lifecycle",
        "Implementation must include web scraping and data augmentation",
        "Use structured project architecture (data/, src/, notebooks/)",
        "Final pipeline must be reproducible",
        "Submit GitHub repository, notebook, report (1500 words), presentation, and poster",
        "Model should support real-time classification use case"
    ],

    "assumptions": [
        "Lexical URL features contain enough signal to detect phishing",
        "Dataset labels (benign/malware/phishing) are accurate",
        "Scraped data sources are reliable and accessible",
        "Training data is representative of real-world URL patterns",
        "Patterns in phishing URLs remain relatively stable during project timeframe"
    ],

    "constraints": [
        "Limited computing power (no distributed systems like Spark in practice)",
        "Time constraint due to academic deadline",
        "Limited dataset size compared to real-world big data scenarios",
        "No budget for paid APIs or large-scale cloud infrastructure",
        "Web scraping may be rate-limited or blocked by some websites"
    ],

    "risks_and_contingencies": [
        {
            "risk": "Scraped data unavailable or inconsistent",
            "probability": "Medium",
            "mitigation": "Use multiple sources or fallback to existing dataset features only"
        },
        {
            "risk": "Class imbalance (few phishing vs many benign URLs)",
            "probability": "High",
            "mitigation": "Use resampling techniques (SMOTE, class weights)"
        },
        {
            "risk": "Model overfitting due to limited dataset",
            "probability": "Medium",
            "mitigation": "Apply cross-validation and regularization techniques"
        },
        {
            "risk": "Feature extraction errors (e.g., malformed URLs)",
            "probability": "Medium",
            "mitigation": "Implement robust preprocessing and validation checks"
        },
        {
            "risk": "Low model performance",
            "probability": "Medium",
            "mitigation": "Experiment with multiple models and feature engineering strategies"
        }
    ],

    "terminology": {
        "Phishing": "A cyberattack where users are tricked into revealing sensitive information via malicious websites",
        "Malicious URL": "A URL that leads to harmful content such as phishing pages or malware downloads",
        "Lexical Features": "Features derived from the structure of the URL string itself (e.g., length, characters)",
        "Obfuscation": "Techniques used to disguise malicious intent in URLs (e.g., encoding, IP usage)",
        "Recall": "Proportion of actual phishing URLs correctly identified",
        "Precision": "Proportion of predicted phishing URLs that are actually phishing",
        "Pipeline": "A sequence of data processing and modeling steps"
    },

    "cost_benefit": (
        "Costs are minimal, primarily consisting of time, computational resources, "
        "and effort required for development and experimentation. "
        "Benefits include improved user safety through early phishing detection, "
        "reduced financial losses from cyberattacks, and the ability to deploy "
        "lightweight real-time detection systems without relying on heavy content analysis."
    )
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Single student (Data Scientist role)"
#     ],
#     "data_sources": [
#       "Malicious URL Dataset (Kaggle)",
#       "Malicious URLs Dataset (40k Samples) from KaggleWeb scraping additional URLs for augmentation if needed"
#     ],
#     "computing": "Local machine (laptop) using CPU-based processing. Google Collab for heavier workloads.",
#     "software": [
#       "Python 3.13.1",
#       "pandas",
#       "numpy",
#       "scikit-learn",
#       "matplotlib / seaborn",
#       "BeautifulSoup / Selenium (for scraping)",
#       "Jupyter Notebook",
#       "Git & GitHub"
#     ]
#   },
#   "requirements": [
#     "Project must follow CRISP-DM lifecycle",
#     "Implementation must include web scraping and data augmentation",
#     "Use structured project architecture (data/, src/, notebooks/)",
#     "Final pipeline must be reproducible",
# ...

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# the original data set described in the asignment description
# has misleading data
# so i am using a smaller dataset that is more accurate (40k Samples) from Kaggle

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "Multiclass Classification (Benign vs Malware vs Phishing vs Defacement)",

    "target_variable": "URL_class",

    "technical_goals": [
        "Build a classification model to predict the class of a URL using only lexical and engineered features",
        "Develop a feature engineering pipeline to extract meaningful patterns from raw URL strings",
        "Compare multiple machine learning models (e.g., Logistic Regression, Random Forest, Gradient Boosting)",
        "Optimize model performance using cross-validation and hyperparameter tuning",
        "Ensure the model can generalize well to unseen data",
        "Design a lightweight pipeline suitable for real-time inference"
    ],

    "success_metrics": [
        "F1-Score (Phishing class) >= 0.85",
        "Recall (Phishing class) >= 0.90",
        "Precision (Phishing class) >= 0.85",
        "Overall Accuracy >= 0.85",
        "ROC-AUC >= 0.90 (if applicable for multiclass setting)",
        "Inference time per prediction < 100ms"
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ...
# BUSINESS TO DATA MINING GOAL MAPPING
# ...
#
# Business Objective : Develop a machine learning model that can accurately classify URLs as benign, malware, or phishing using only lexical features (e.g., URL length, special characters, obfuscation patterns) in real-time.
# Problem Type       : Multiclass Classification (Benign vs Malware vs Phishing vs Defacement)
# Target Variable    : URL_class
#
# Technical Goals:
#   - Build a classification model to predict the class of a URL using only lexical and engineered features
#   - Develop a feature engineering pipeline to extract meaningful patterns from raw URL strings
#   - Compare multiple machine learning models (e.g., Logistic Regression, Random Forest, Gradient Boosting)
#   - Optimize model performance using cross-validation and hyperparameter tuning
#   - Ensure the model can generalize well to unseen data
#   - Design a lightweight pipeline suitable for real-time inference
#
# Success Metrics:
#   - F1-Score (Phishing class) >= 0.85
# ...

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
project_plan = {
    "tools": [
        "Python 3.13",
        "pandas",
        "numpy",
        "scikit-learn",
        "matplotlib",
        "seaborn",
        "BeautifulSoup",
        "Selenium",
        "Jupyter Notebook",
        "Git & GitHub"
    ],

    "techniques": [
        "Feature Engineering (URL lexical feature extraction)",
        "Exploratory Data Analysis (EDA)",
        "Classification (Logistic Regression, Random Forest, Gradient Boosting)",
        "Cross-Validation",
        "Hyperparameter Tuning (Grid Search / Random Search)",
        "Class Imbalance Handling (SMOTE / class weights)",
        "Pipeline Construction (sklearn.pipeline)"
    ],

    "timeline": [
        {"phase": "Business Understanding", "duration": "Week 1", "status": "Completed"},
        {"phase": "Data Understanding", "duration": "Week 1-2", "status": "In Progress"},
        {"phase": "Data Preparation (Cleaning + Feature Engineering)", "duration": "Week 2-3", "status": "Not Started"},
        {"phase": "Web Scraping & Data Augmentation", "duration": "Week 3", "status": "Not Started"},
        {"phase": "Modelling", "duration": "Week 4", "status": "Not Started"},
        {"phase": "Evaluation", "duration": "Week 5", "status": "Not Started"},
        {"phase": "Final Notebook & Optimization", "duration": "Week 5", "status": "Not Started"},
        {"phase": "Report Writing", "duration": "Week 6", "status": "Not Started"},
        {"phase": "Presentation & Poster Preparation", "duration": "Week 6", "status": "Not Started"}
    ],

    "dependencies": [
        "Dataset must be collected and cleaned before feature engineering can begin",
        "Feature engineering must be completed before model training",
        "Web scraping must be completed before dataset merging and final modeling",
        "Model training depends on successful preprocessing and feature extraction",
        "Evaluation depends on trained models and defined metrics",
        "Final report depends on completion of all previous phases",
        "Web scraping may depend on external website availability and rate limits"
    ],

    "tool_justification": (
        "Python is chosen due to its strong ecosystem for data science and machine learning. "
        "Pandas and NumPy enable efficient data manipulation, while scikit-learn provides "
        "robust implementations of machine learning algorithms and pipeline tools. "
        "Matplotlib and Seaborn are used for visualization and exploratory analysis. "
        "BeautifulSoup and Selenium are selected for web scraping to augment the dataset. "
        "The chosen techniques (classification models, feature engineering, and pipeline design) "
        "are appropriate for structured tabular data and allow for interpretable and efficient "
        "real-time predictions. The overall toolset is lightweight and scalable, making it suitable "
        "for both local development and potential extension to larger datasets."
    )
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ...
# PROJECT PLAN
# ...
#
# Tools: Python 3.13, pandas, numpy, scikit-learn, matplotlib, seaborn, BeautifulSoup, Selenium, Jupyter Notebook, Git & GitHub
# Techniques: Feature Engineering (URL lexical feature extraction), Exploratory Data Analysis (EDA), Classification (Logistic Regression, Random Forest, Gradient Boosting), Cross-Validation, Hyperparameter Tuning (Grid Search / Random Search), Class Imbalance Handling (SMOTE / class weights), Pipeline Construction (sklearn.pipeline)
#
# Timeline:
#   [ Completed  ] Business Understanding    | Week 1
#   [In Progress ] Data Understanding        | Week 1-2
#   [Not Started ] Data Preparation (Cleaning + Feature Engineering) | Week 2-3
#   [Not Started ] Web Scraping & Data Augmentation | Week 3
#   [Not Started ] Modelling                 | Week 4
#   [Not Started ] Evaluation                | Week 5
#   [Not Started ] Final Notebook & Optimization | Week 5
#   [Not Started ] Report Writing            | Week 6
# ...

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ...
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ...
#
# Primary Objective  : Develop a machine learning model that can accurately classify URLs as benign, malware, or phishing using only lexical features (e.g., URL length, special characters, obfuscation patterns) in real-time.
# Problem Type       : Multiclass Classification (Benign vs Malware vs Phishing vs Defacement)
# Target Variable    : URL_class
# Tools Planned      : Python 3.13, pandas, numpy, scikit-learn, matplotlib, seaborn, BeautifulSoup, Selenium, Jupyter Notebook, Git & GitHub
# Techniques Planned : Feature Engineering (URL lexical feature extraction), Exploratory Data Analysis (EDA), Classification (Logistic Regression, Random Forest, Gradient Boosting), Cross-Validation, Hyperparameter Tuning (Grid Search / Random Search), Class Imbalance Handling (SMOTE / class weights), Pipeline Construction (sklearn.pipeline)
