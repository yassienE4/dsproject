# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# TODO: Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

evaluation = {
    "business_criteria": [
        {
            "criterion": "Accurately detect malicious URLs (phishing, malware, defacement)",
            "target": "High detection rate (Recall >= 0.85 for malicious classes)",
            "achieved": "Recall ranges between 0.78 and 0.86 across malicious classes",
            "met": False
        },
        {
            "criterion": "Minimize false positives (benign incorrectly flagged)",
            "target": "Precision >= 0.85 for benign class",
            "achieved": "Precision for benign class = 0.89",
            "met": True
        },
        {
            "criterion": "Enable real-time detection with efficient performance",
            "target": "Fast inference with lightweight features",
            "achieved": "Model uses simple lexical features and tree-based inference",
            "met": True
        }
    ],

    "technical_criteria": [
        {
            "metric": "F1-Score (weighted)",
            "target": ">= 0.85",
            "achieved": 0.8583,
            "met": True
        },
        {
            "metric": "Accuracy",
            "target": ">= 0.85",
            "achieved": 0.8591,
            "met": True
        },
        {
            "metric": "Recall (minority classes)",
            "target": ">= 0.85",
            "achieved": "Lowest recall = 0.78",
            "met": False
        }
    ],

    "overall_assessment": (
        "The Random Forest (Tuned) model meets most technical and business criteria, "
        "achieving strong overall accuracy and F1-score. It performs well across most classes, "
        "but slightly underperforms on one minority class in terms of recall. "
        "Overall, the model is suitable for deployment with minor limitations."
    ),

    "approved_models": [
        "Random Forest (Tuned)"
    ],

    "rejected_models": [
        "Logistic Regression",
        "SVM",
        "Gradient Boosting",
        "Random Forest"
    ]
}

# %%
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)

print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    if c['met'] == True:
        status = 'PASS'
    elif c['met'] == False:
        status = 'FAIL'
    else:
        status = 'PARTIAL'
        
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")

print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    if c['met'] == True:
        status = 'PASS'
    elif c['met'] == False:
        status = 'FAIL'
    else:
        status = 'PARTIAL'
        
    print(f"  [{status}] {c['metric']}: Target {c['target']}  |  Achieved: {c['achieved']}")

print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ============================================================
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ============================================================
#
# --- Business Criteria ---
#   [FAIL] Accurately detect malicious URLs (phishing, malware, defacement)
#          Target: High detection rate (Recall >= 0.85 for malicious classes)  |  Achieved: Recall ranges between 0.78 and 0.86 across malicious classes
#   [PASS] Minimize false positives (benign incorrectly flagged)
#          Target: Precision >= 0.85 for benign class  |  Achieved: Precision for benign class = 0.89
#   [PASS] Enable real-time detection with efficient performance
#          Target: Fast inference with lightweight features  |  Achieved: Model uses simple lexical features and tree-based inference
#
# --- Technical Criteria ---
#   [PASS] F1-Score (weighted): Target >= 0.85  |  Achieved: 0.8583
#   [PASS] Accuracy: Target >= 0.85  |  Achieved: 0.8591
#   [FAIL] Recall (minority classes): Target >= 0.85  |  Achieved: Lowest recall = 0.78
#
# Overall: The Random Forest (Tuned) model meets most technical and business criteria, achieving strong overall accuracy and F1-score. It performs well across most classes, but slightly underperforms on one minority class in terms of recall. Overall, the model is suitable for deployment with minor limitations.
# Approved models: ['Random Forest (Tuned)']
# Rejected models: ['Logistic Regression', 'SVM', 'Gradient Boosting', 'Random Forest']

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# TODO: Review the end-to-end process.

process_review = {
    "checklist": [
        {
            "item": "All relevant data sources were considered",
            "status": "Partial",
            "notes": "Primary dataset used with no external enrichment beyond initial scope"
        },
        {
            "item": "Data preparation was thorough and documented",
            "status": "Yes",
            "notes": "Included cleaning, feature engineering, encoding, scaling, and formatting"
        },
        {
            "item": "No data leakage between train and test sets",
            "status": "Yes",
            "notes": "Train/test split performed before modeling with proper separation"
        },
        {
            "item": "Multiple modelling techniques were compared",
            "status": "Yes",
            "notes": "Logistic Regression, Random Forest, Gradient Boosting, and SVM evaluated"
        },
        {
            "item": "Hyperparameters were tuned appropriately",
            "status": "Yes",
            "notes": "GridSearchCV applied to Random Forest with cross-validation"
        },
        {
            "item": "Results are reproducible (random seeds set)",
            "status": "Yes",
            "notes": "Random seed fixed at 42 across all steps"
        },
        {
            "item": "Bias and fairness have been considered",
            "status": "Partial",
            "notes": "Class imbalance identified and discussed, but not fully mitigated"
        },
        {
            "item": "Ethical implications have been reviewed",
            "status": "Yes",
            "notes": "Considered risks of false positives/negatives in cybersecurity context"
        }
    ],

    "overall_quality": (
        "The project demonstrates a strong and well-structured data science workflow, "
        "following the CRISP-DM methodology. Data preparation and modeling were thorough, "
        "and multiple models were evaluated effectively. Minor improvements could be made "
        "in handling class imbalance and incorporating additional data sources."
    ),

    "areas_for_improvement": [
        "Apply techniques to address class imbalance (e.g., class weights or SMOTE)",
        "Incorporate additional external data sources for richer feature representation",
        "Explore more advanced models or feature engineering techniques",
        "Perform deeper error analysis on minority classes",
        "Consider excluding binary features from scaling for better interpretability"
    ]
}

# %%
print("=" * 60)
print("PROCESS REVIEW CHECKLIST")
print("=" * 60)

for item in process_review['checklist']:
    print(f"[{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")
    print()  # spacing between items

print("=" * 60)
print("OVERALL QUALITY")
print("=" * 60)
print(process_review['overall_quality'])

if process_review['areas_for_improvement']:
    print("\nAREAS FOR IMPROVEMENT:")
    for area in process_review['areas_for_improvement']:
        print(f"- {area}")
# Out:
# ============================================================
# PROCESS REVIEW CHECKLIST
# ============================================================
# [Partial ] All relevant data sources were considered
#            Note: Primary dataset used with no external enrichment beyond initial scope
#
# [  Yes   ] Data preparation was thorough and documented
#            Note: Included cleaning, feature engineering, encoding, scaling, and formatting
#
# [  Yes   ] No data leakage between train and test sets
#            Note: Train/test split performed before modeling with proper separation
#
# [  Yes   ] Multiple modelling techniques were compared
#            Note: Logistic Regression, Random Forest, Gradient Boosting, and SVM evaluated
#
# [  Yes   ] Hyperparameters were tuned appropriately
#            Note: GridSearchCV applied to Random Forest with cross-validation
#
# [  Yes   ] Results are reproducible (random seeds set)
#            Note: Random seed fixed at 42 across all steps
#
# [Partial ] Bias and fairness have been considered
#            Note: Class imbalance identified and discussed, but not fully mitigated
#
# [  Yes   ] Ethical implications have been reviewed
#            Note: Considered risks of false positives/negatives in cybersecurity context
#
# ============================================================
# OVERALL QUALITY
# ============================================================
# The project demonstrates a strong and well-structured data science workflow, following the CRISP-DM methodology. Data preparation and modeling were thorough, and multiple models were evaluated effectively. Minor improvements could be made in handling class imbalance and incorporating additional data sources.
#
# AREAS FOR IMPROVEMENT:
# - Apply techniques to address class imbalance (e.g., class weights or SMOTE)
# - Incorporate additional external data sources for richer feature representation
# - Explore more advanced models or feature engineering techniques
# - Perform deeper error analysis on minority classes
# - Consider excluding binary features from scaling for better interpretability

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# TODO: Determine and document the next steps.

next_steps = {
    "decision": "",  # "Proceed to Deployment" / "Iterate" / "Terminate"
    "rationale": "",
    "if_iterating": {
        "return_to_phase": "",  # e.g., "Phase 3: Data Preparation"
        "specific_actions": [
            # "Action 1: Try additional feature engineering",
            # "Action 2: Collect more data for underrepresented classes"
        ]
    },
    "if_deploying": {
        "selected_model": "",  # Name of the model to deploy
        "deployment_priority": ""  # e.g., "High", "Medium"
    }
}

# %%
# Display the decision
# print("=" * 60)
# print("NEXT STEPS DECISION")
# print("=" * 60)
# print(f"\nDecision  : {next_steps['decision']}")
# print(f"Rationale : {next_steps['rationale']}")
#
# if next_steps['decision'] == 'Iterate':
#     print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
#     for action in next_steps['if_iterating']['specific_actions']:
#         print(f"  - {action}")
# elif next_steps['decision'] == 'Proceed to Deployment':
#     print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
#     print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
